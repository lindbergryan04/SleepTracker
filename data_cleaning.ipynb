# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict

# Directory containing user folders
user_data_dir = "/Users/audrey/Desktop/dsc106/SleepTracker/data/user_data"

# Activity categories as per dataset documentation
activity_categories = {
    1: 'sleeping',
    2: 'laying down',
    3: 'sitting',
    4: 'light movement',
    5: 'medium movement',
    6: 'heavy activity',
    7: 'eating',
    8: 'small screen',
    9: 'large screen',
    10: 'caffeinated drink',
    11: 'smoking',
    12: 'alcohol'
}

# Create a dictionary for storing the result
user_activity_profiles = defaultdict(lambda: np.zeros(12))

# Loop through each user folder and calculate activity time
for user_folder in os.listdir(user_data_dir):
    activity_file = os.path.join(user_data_dir, user_folder, "Activity.csv")
    if os.path.exists(activity_file):
        try:
            df = pd.read_csv(activity_file)
            for i in range(1, 13):  # for each activity type
                total_time = df[df['Activity'] == i].apply(
                    lambda row: pd.Timedelta(
                        pd.to_datetime(row['End'].replace("24:00", "00:00"), format='%H:%M') -
                        pd.to_datetime(row['Start'].replace("24:00", "00:00"), format='%H:%M')
                    ).seconds / 60.0,
                    axis=1
                ).sum()
                user_activity_profiles[user_folder][i - 1] = total_time
        except Exception as e:
            print(f"Error reading {activity_file}: {e}")

# Convert to DataFrame for analysis
activity_profiles_df = pd.DataFrame.from_dict(user_activity_profiles, orient='index', columns=list(activity_categories.values()))

# Display (optional, in Jupyter)
activity_profiles_df.head()
# Out:
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_3/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_4/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_6/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_21/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_17/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_11/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# Error reading /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_18/Activity.csv: time data "24:00" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
#          sleeping  laying down  sitting  light movement  medium movement  \
# user_5        0.0        300.0     50.0             0.0              0.0
# user_2       12.0         44.0    101.0            17.0              0.0
# user_4        1.0        175.0      0.0             0.0              0.0
# user_22       0.0         20.0    490.0             0.0              0.0
# user_14      46.0        105.0     92.0             0.0              0.0
#
#          heavy activity  eating  small screen  large screen  \
# user_5            120.0   135.0           0.0          20.0
# user_2             52.0   160.0          30.0           2.0
# user_4            110.0   235.0           0.0           0.0
# user_22            80.0   120.0           0.0           0.0
# user_14            58.0   589.0         118.0           0.0
#
#          caffeinated drink  smoking  alcohol
# user_5                 0.0      0.0      0.0
# user_2                 0.0      0.0     20.0
# user_4                 0.0      0.0      0.0
# user_22                0.0     10.0      0.0
# user_14                0.0      0.0      5.0

# %%
import os

# Start at your current notebook's directory
base_path = os.getcwd()

# See what's inside
for root, dirs, files in os.walk(base_path):
    for dir_name in dirs:
        print(os.path.join(root, dir_name))
# Out:
# /Users/audrey/Desktop/dsc106/SleepTracker/.git
# /Users/audrey/Desktop/dsc106/SleepTracker/data
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/objects
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/info
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/logs
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/hooks
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/refs
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/branches
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/objects/pack
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/objects/info
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/logs/refs
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/logs/refs/heads
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/logs/refs/remotes
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/logs/refs/remotes/origin
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/refs/heads
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/refs/tags
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/refs/remotes
# /Users/audrey/Desktop/dsc106/SleepTracker/.git/refs/remotes/origin
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_5
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_2
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_3
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_4
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_22
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_14
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_13
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_12
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_15
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_1
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_6
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_8
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_9
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_7
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_21
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_19
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_10
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_17
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_16
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_11
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_18
# /Users/audrey/Desktop/dsc106/SleepTracker/data/user_data/user_20

# %% [markdown]
# Efficiency Chart Data

# %%
import os
import pandas as pd

base_path = "data/user_data"
merged_users = []

for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)

    if os.path.isdir(folder_path) and folder.startswith("user_"):
        user_id = int(folder.split("_")[1])

        sleep_path = os.path.join(folder_path, "sleep.csv")
        info_path = os.path.join(folder_path, "user_info.csv")
        saliva_path = os.path.join(folder_path, "saliva.csv")

        if os.path.exists(sleep_path) and os.path.exists(info_path):
            sleep_df = pd.read_csv(sleep_path)
            info_df = pd.read_csv(info_path)

            sleep_df["user_id"] = user_id
            info_df["user_id"] = user_id

            merged = sleep_df.merge(info_df, on="user_id")

            # Handle saliva data if available
            if os.path.exists(saliva_path):
                saliva_df = pd.read_csv(saliva_path)

                # Clean column headers and values
                saliva_df.columns = saliva_df.columns.str.strip()
                if "SAMPLES" in saliva_df.columns:
                    saliva_df["SAMPLES"] = saliva_df["SAMPLES"].astype(str).str.strip().str.lower()

                    # Extract the 'before sleep' row (string match)
                    before_sleep_row = saliva_df[saliva_df["SAMPLES"] == "before sleep"]

                    if not before_sleep_row.empty:
                        cortisol = before_sleep_row["Cortisol NORM"].values[0]
                        melatonin = before_sleep_row["Melatonin NORM"].values[0]

                        merged["Cortisol_NORM"] = cortisol
                        merged["Melatonin_NORM"] = melatonin

            merged_users.append(merged)

# Filter out empty DataFrames
non_empty_merged = [df for df in merged_users if not df.empty]

# Concatenate all user data
all_users_df = pd.concat(non_empty_merged, ignore_index=True)

# Drop unwanted index columns
all_users_df.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y"], errors="ignore", inplace=True)

# Set index to user_id, sort by user_id
all_users_df.set_index("user_id", inplace=True)
all_users_df.sort_index(inplace=True)

# Preview
all_users_df.head()
# Out:
#          In Bed Date In Bed Time  Out Bed Date Out Bed Time  Onset Date  \
# user_id
# 1                  2       03:57             2        07:30           2
# 1                  2       00:46             2        03:31           2
# 2                  2       00:50             2        06:22           2
# 3                  1       22:29             1        05:52           1
# 4                  2       00:57             2        07:10           2
#
#         Onset Time  Latency  Efficiency  Total Minutes in Bed  \
# user_id
# 1            03:57        0       92.02                   213
# 1            00:46        0       87.27                   165
# 2            00:54        4       73.49                   332
# 3            22:32        3       79.23                   443
# 4            01:01        4       85.52                   373
#
#          Total Sleep Time (TST)  ...  Average Awakening Length  \
# user_id                          ...
# 1                           196  ...                      1.89
# 1                           144  ...                      2.33
# 2                           244  ...                      4.67
# 3                           351  ...                      5.56
# 4                           319  ...                      1.79
#
#          Movement Index  Fragmentation Index  Sleep Fragmentation Index  \
# user_id
# 1                 8.920                0.000                      8.920
# 1                 9.091               10.000                     19.091
# 2                15.060                5.556                     20.616
# 3                18.962                0.000                     18.962
# 4                 8.847               14.286                     23.133
#
#          Gender  Weight Height  Age  Cortisol_NORM  Melatonin_NORM
# user_id
# 1             M      65    169   29       0.034137    1.738385e-08
# 1             M      65    169   29       0.034137    1.738385e-08
# 2             M      95    183   27       0.021186    1.676342e-08
# 3             M      70    174   34       0.012142    5.714439e-09
# 4             M      76    180   27       0.023772    2.149747e-08
#
# [5 rows x 22 columns]

# %% [markdown]
# Write to csv

# %%
#all_users_df.to_csv("data/clean_data/user_sleep_data.csv", index=True)

# %%
f = pd.read_csv('data/user_data/user_21/questionnaire.csv')
f.columns.str.contains('panas_neg_')
per_u['Avg_Neg_PANAs'] = per_u.loc[:, panas_columns].mean(axis=1)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#         True,  True])

# %%
import pandas as pd

output = pd.DataFrame()
curr_user = 1

for i in range(22):
    path_name = "data/user_data/user_" + str(curr_user) + "/questionnaire.csv"
    per_u = pd.read_csv(path_name)

    panas_columns = per_u.columns.str.contains('panas_neg_')
    per_u['Avg_Neg_PANAs'] = per_u.loc[:, panas_columns].mean(axis=1)
    per_u['user_id'] =  str(curr_user) 
    output = pd.concat([output, per_u], ignore_index=True)

    curr_user += 1

output
# Out:
#     Unnamed: 0   MEQ  STAI1  STAI2  Pittsburgh  Daily_stress  BISBAS_bis  \
# 0            0  47.0   41.0   43.0         5.0          23.0        22.0
# 1            0  52.0   24.0   39.0         7.0          26.0        26.0
# 2            0  59.0   27.0   27.0         8.0          11.0        19.0
# 3            0  60.0   28.0   40.0         4.0          10.0        20.0
# 4            0  52.0   54.0   47.0         8.0          41.0        25.0
# 5            0  48.0   32.0   47.0         9.0          41.0        19.0
# 6            0  46.0   33.0    0.0         7.0          69.0        19.0
# 7            0  64.0   32.0   39.0         3.0          74.0        24.0
# 8            0  44.0   36.0   41.0         9.0          38.0        20.0
# 9            0  38.0   39.0   46.0         4.0          14.0        19.0
# 10           0  38.0   36.0   43.0         7.0          17.0        23.0
# 11           0  50.0   27.0   33.0         4.0          48.0        20.0
# 12           0  48.0   30.0   43.0         4.0          27.0        22.0
# 13           0  59.0   48.0   45.0         2.0          26.0        24.0
# 14           0  58.0   52.0   42.0         5.0          35.0        25.0
# 15           0  45.0   29.0   41.0         5.0          32.0        26.0
# 16           0  49.0   34.0   49.0         3.0          20.0        22.0
# 17           0  55.0   33.0   44.0         5.0          32.0        26.0
# 18           0  44.0   26.0   35.0         4.0          31.0        21.0
# 19           0  44.0   44.0   42.0         5.0          22.0        22.0
# 20           0  55.0   38.0   35.0         4.0          30.0        23.0
